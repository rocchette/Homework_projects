# %%
# !pip install psycopg2
# Out:
# ...
#   Using cached psycopg2-2.9.6.tar.gz (383 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Users/victoria/opt/anaconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/4f/zkg9tmbs22l_kzpykf2vs61h0000gn/T/pip-install-rum7fq7w/psycopg2_e152b1120ec64d05be352f3696e21dae/setup.py'"'"'; __file__='"'"'/private/var/folders/4f/zkg9tmbs22l_kzpykf2vs61h0000gn/T/pip-install-rum7fq7w/psycopg2_e152b1120ec64d05be352f3696e21dae/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/4f/zkg9tmbs22l_kzpykf2vs61h0000gn/T/pip-pip-egg-info-yybi9pvz
# ...

# %%
import psycopg2
conn = psycopg2.connect(dbname='test', user='db_user', 
                        password='mypassword', host='localhost')
cursor = conn.cursor()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 import psycopg2
#       2 conn = psycopg2.connect(dbname='test', user='db_user',
#       3                         password='mypassword', host='localhost')
#       4 cursor = conn.cursor()
#
# ModuleNotFoundError: No module named 'psycopg2'
